# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
file_path = '/content/drive/My Drive/project/alzheimers_disease_data.csv'  # Correct path
df = pd.read_csv(file_path)
df.head()
# Out:
#    PatientID  Age  Gender  Ethnicity  EducationLevel        BMI  Smoking  \
# 0       4751   73       0          0               2  22.927749        0
# 1       4752   89       0          0               0  26.827681        0
# 2       4753   73       0          3               1  17.795882        0
# 3       4754   74       1          0               1  33.800817        1
# 4       4755   89       0          0               0  20.716974        0
#
#    AlcoholConsumption  PhysicalActivity  DietQuality  ...  MemoryComplaints  \
# 0           13.297218          6.327112     1.347214  ...                 0
# 1            4.542524          7.619885     0.518767  ...                 0
# 2           19.555085          7.844988     1.826335  ...                 0
# 3           12.209266          8.428001     7.435604  ...                 0
# 4           18.454356          6.310461     0.795498  ...                 0
#
#    BehavioralProblems       ADL  Confusion  Disorientation  \
# ...

# %%
feature = df.drop(['PatientID', 'DoctorInCharge'], axis=1)
feature.Diagnosis.value_counts()
# Out:
# Diagnosis
# 0    1389
# 1     760
# Name: count, dtype: int64

# %%
df.head().T
# Out:
#                                     0           1           2           3  \
# PatientID                        4751        4752        4753        4754
# Age                                73          89          73          74
# Gender                              0           0           0           1
# Ethnicity                           0           0           3           0
# EducationLevel                      2           0           1           1
# BMI                         22.927749   26.827681   17.795882   33.800817
# Smoking                             0           0           0           1
# AlcoholConsumption          13.297218    4.542524   19.555085   12.209266
# PhysicalActivity             6.327112    7.619885    7.844988    8.428001
# DietQuality                  1.347214    0.518767    1.826335    7.435604
# SleepQuality                 9.025679    7.151293    9.673574    8.392554
# FamilyHistoryAlzheimers             0           0           1           0
# ...

# %%
#Before smoke

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report
X_orig = feature.drop(columns=["Diagnosis"])
y_orig = feature["Diagnosis"]

X_train, X_test, y_train, y_test = train_test_split(X_orig, y_orig, test_size=0.2, random_state=42)

model = RandomForestClassifier(random_state=42)
model.fit(X_train, y_train)
y_pred = model.predict(X_test)

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.91      0.98      0.94       277
#            1       0.96      0.82      0.89       153
#
#     accuracy                           0.93       430
#    macro avg       0.94      0.90      0.92       430
# weighted avg       0.93      0.93      0.92       430

# %%
#After smoke

# %%
from imblearn.over_sampling import SMOTE
X = feature.drop(columns=["Diagnosis"])
y = feature["Diagnosis"]
smote = SMOTE(random_state=42)
X_sm, y_sm = smote.fit_resample(X, y)

# Check new class distribution
print(y_sm.value_counts(normalize=True) * 100)
# Out:
# Diagnosis
# 0    50.0
# 1    50.0
# Name: proportion, dtype: float64

# %%
print (y_sm.value_counts())
# Out:
# Diagnosis
# 0    1389
# 1    1389
# Name: count, dtype: int64

# %%
x_train,x_test,y_train,y_test=train_test_split(X_sm,y_sm,test_size=0.2,random_state=42)
model = RandomForestClassifier(random_state=42)
model.fit(x_train, y_train)
y_pred = model.predict(x_test)

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.84      0.96      0.90       273
#            1       0.95      0.83      0.89       283
#
#     accuracy                           0.89       556
#    macro avg       0.90      0.89      0.89       556
# weighted avg       0.90      0.89      0.89       556

# %%
#Befoe smoke, the accuracy is 0.93. After smoke, the accuracy is 0.89.
#Overall accuracy is higher before smoke.
